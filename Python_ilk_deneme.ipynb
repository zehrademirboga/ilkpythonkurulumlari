# %% [markdown]
# Python programlama dilinde print komutu ekrandan kullanıcıya bilgi veren bir koddur.
#
#
# 06.08.2024 - Veri Yapıları ve Algoritma dersi ilk kodlama çıktısıdır.
# İGÜ İSTKA SİBER AKADEMİ MERKEZİ -

# %%
print("Merhaba, Avcılar!") # print ekrana çıktı veren bir koddur.
# Out:
# Merhaba, Avcılar!

# %%
import sys # import python programlama dilinde yazılıma kütüphaneye eklemeye yarayan bir kod bloğudur.
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod bloğudur.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
